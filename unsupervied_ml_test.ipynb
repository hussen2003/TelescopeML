# %%
from TelescopeML.unsupervised_ml import *
import pandas as pd
import os

# %%
os.environ["TelescopeML_reference_data"] = "C:\\Users\\husse\\Desktop\\reference_data"

__reference_data_path__ = os.getenv("TelescopeML_reference_data")
__reference_data_path__ 


# Note: insert the directory of the reference_data if you get an error reading the reference data!!!
# __reference_data_path__ = 'INSERT_DIRECTORY_OF_reference_data'
# Out:
# 'C:\\Users\\husse\\Desktop\\reference_data'

# %%
data = pd.read_csv(os.path.join(__reference_data_path__, 
                                    'training_datasets', 
                                    'browndwarf_R100_v4_newWL_v3.csv.bz2'), compression='bz2')
#data = data[['gravity', 'temperature', 'c_o_ratio', 'metallicity']]
data
# Out:
#        gravity  temperature  c_o_ratio  metallicity         2.512  \
# 0         5.00         1100       0.25         -1.0  9.103045e-08
# 1         5.00         1100       0.25         -0.7  9.103045e-08
# 2         5.00         1100       0.25         -0.5  9.103045e-08
# 3         5.00         1100       0.25         -0.3  9.103045e-08
# 4         5.00         1100       0.25          0.0  9.103045e-08
# ...        ...          ...        ...          ...           ...
# 30883     3.25         1000       2.50          0.7  1.533414e-08
# 30884     3.25         1000       2.50          1.0  6.942763e-09
# 30885     3.25         1000       2.50          1.3  3.758895e-09
# 30886     3.25         1000       2.50          1.7  3.150169e-09
# 30887     3.25         1000       2.50          2.0  2.665630e-09
#
#               2.487         2.462         2.438         2.413         2.389  \
# 0      1.181658e-07  1.307868e-07  1.269229e-07  1.159179e-07  8.925110e-08
# ...

# %%
data.describe()
# Out:
#             gravity   temperature     c_o_ratio   metallicity         2.512  \
# count  30888.000000  30888.000000  30888.000000  30888.000000  3.088800e+04
# mean       4.250000    971.794872      1.291667      0.416667  5.069814e-07
# std        0.790582    657.199180      0.796053      0.920009  1.328403e-06
# min        3.000000    200.000000      0.250000     -1.000000  1.163528e-20
# 25%        3.500000    425.000000      0.500000     -0.350000  1.877350e-11
# 50%        4.250000    750.000000      1.250000      0.400000  2.567353e-09
# 75%        5.000000   1500.000000      2.000000      1.075000  2.571831e-07
# max        5.500000   2400.000000      2.500000      2.000000  1.176544e-05
#
#               2.487         2.462         2.438         2.413         2.389  \
# count  3.088800e+04  3.088800e+04  3.088800e+04  3.088800e+04  3.088800e+04
# mean   5.652753e-07  6.021823e-07  6.174451e-07  6.374291e-07  6.751319e-07
# ...

# %% [markdown]
# # Kmeans
# Allows for choosing how many clusters and which feature to compare, for example: gravity and Temperature

# %%
unsupervised = UnsupervisedMethods(data)

#k-means without PCA
fig = unsupervised.visualize_clustering(method='kmeans', use_pca=False, n_clusters=2, x_col='gravity', y_col='temperature')

#K-means with PCA
fig2 = unsupervised.visualize_clustering(method='kmeans', use_pca=True, n_clusters=2, x_col='c_o_ratio', y_col='gravity')
plt.show()

# %% [markdown]
# # DBSCAN

# %% [markdown]
# Allows choosing different epsilon and min_simple values which can affect how clusters are calculated

# %%
unsupervised = UnsupervisedMethods(data)
fig3 = unsupervised.visualize_clustering(method='dbscan', use_pca=False, eps=0.3, min_samples=5, x_col='gravity', y_col='temperature')
fig4 = unsupervised.visualize_clustering(method='dbscan', use_pca=True, eps=0.3, min_samples=5)
plt.show()
